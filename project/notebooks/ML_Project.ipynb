# %% [markdown]
# # 🏥 Prediksi Kelangsungan Hidup Pasien Haberman
# ## Project Machine Learning - CS2025
# **Nama:**
# **NIM:**
#
# ### Dataset: Haberman's Survival Dataset (UCI)

# %%
# --- IMPORT LIBRARIES ---
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import os
import time

print("✅ Libraries imported")

# %%
# --- LOAD DATASET ---
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/haberman/haberman.data"
df = pd.read_csv(url, header=None)
df.columns = ['Age', 'Year_of_Operation', 'Positive_Axillary_Nodes', 'Survival_Status']

# Preprocessing target
df['Survival_Status'] = df['Survival_Status'].apply(lambda x: 0 if x == 1 else 1)

print(f"Dataset shape: {df.shape}")
print(df.head())

# %% [markdown]
# ### 🧠 Model Architecture: MLP Neural Network

# %%
# --- BUILD AND TRAIN MODEL ---
# KODE MODEL ANDA DI SINI
# Copy-paste kode training model Anda di cell ini

print("📝 Copy kode training Anda di sini")
